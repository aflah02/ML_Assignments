# %%
from utils import *

# %%
ds = dataset(10000)

# %%
data = ds.get()

# %%
pta = Perceptron(epochs=1000, learning_rate=0.01, min_error_threshold=0.01)

# %%
pta.train(data, verbose=1)
# Out:
# Epoch: 0, Error: 202.0
# Epoch: 1, Error: 0.0
# (array([0.3771288 , 0.35041172]), -0.5232282895307699)

# %%
pta.plot_decision_boundary(data, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %%
data2 = ds.get(addNoise=True)

# %%
pta2 = Perceptron(epochs=1000, learning_rate=0.01, min_error_threshold=0.01)

# %%
pta2.train(data2, verbose=1)
# Out:
# Epoch: 0, Error: 142.0
# Epoch: 1, Error: 5.0
# Epoch: 2, Error: 3.0
# Epoch: 3, Error: 2.0
# Epoch: 4, Error: 2.0
# Epoch: 5, Error: 0.0
# (array([-0.50524204,  0.89296811]), -1.3027535739486935)

# %%
pta2.plot_decision_boundary(data2, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>
