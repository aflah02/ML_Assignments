# %%
from utils import *

# %% [markdown]
# ### 1) Making The Dataset

# %%
ds = dataset(10000)

# %%
data = ds.get()
noisy_data = ds.get(addNoise=True)

# %% [markdown]
# ## 2) Plotting the Dataset

# %%
plot_dataset(data, 'Data')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_dataset(noisy_data, 'Noisy Data')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ## 3) PTA Training

# %% [markdown]
# #### Training on Noise Free Data

# %%
pta = Perceptron(epochs=1000, min_error_threshold=0.01)

# %%
pta.train(data, verbose=1)
# Out:
# Epoch: 0, Error: 4.0
# Epoch: 1, Error: 0.0
# (array([0.43393077, 1.03850596]), -1.473882201673866)

# %% [markdown]
# #### Decision Boundary for Noise Free Data

# %%
pta.plot_decision_boundary(data, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Training for Noisy Data

# %%
pta2 = Perceptron(epochs=1000, min_error_threshold=0.01)

# %%
pta2.train(noisy_data, verbose=1)
# Out:
# Epoch: 0, Error: 10.0
# Epoch: 1, Error: 0.0
# (array([-0.07302081,  2.59262166]), -3.858634973283432)

# %% [markdown]
# #### Decision Boundary for Noisy Data

# %%
pta2.plot_decision_boundary(noisy_data, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### 4) PTA With Fixed Bias

# %% [markdown]
# #### For Noise Free Data

# %%
pta3 = Perceptron(epochs=1000, min_error_threshold=0.01)

# %%
pta3.train(data, verbose=0, fixedBias=True, bias=0)
# Out:
# (array([-0.56148381,  3.33645619]), 0)

# %%
pta3.plot_decision_boundary(data, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### For Noisy Data

# %%
pta4 = Perceptron(epochs=1000, min_error_threshold=0.01)

# %%
pta4.train(noisy_data, verbose=0, fixedBias=True, bias=0)
# Out:
# (array([-1.50761773,  0.84392123]), 0)

# %%
pta4.plot_decision_boundary(noisy_data, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### 5

# %%
from utils import *

# %%
xor_dataset = logicalOperatorDataset('XOR').get()
and_dataset = logicalOperatorDataset('AND').get()
or_dataset = logicalOperatorDataset('OR').get()

# %% [markdown]
# #### Learnable Bias (AND)

# %%
pta_and = Perceptron(epochs=1000, min_error_threshold=0.01)
pta_and.train(and_dataset, verbose=1)
# Out:
# Epoch: 0, Error: 2
# Epoch: 1, Error: 2
# Epoch: 2, Error: 3
# Epoch: 3, Error: 2
# Epoch: 4, Error: 1
# Epoch: 5, Error: 0
# (array([1.85952268, 0.90473795]), -2.1049128221630453)

# %%
pta_and.plot_decision_boundary(and_dataset, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Learnable Bias (OR)

# %%
pta_or = Perceptron(epochs=1000, min_error_threshold=0.01)
pta_or.train(or_dataset, verbose=1)
# Out:
# Epoch: 0, Error: 2
# Epoch: 1, Error: 2
# Epoch: 2, Error: 1
# Epoch: 3, Error: 0
# (array([2.28931528, 1.28651685]), -0.9490565315272737)

# %%
pta_or.plot_decision_boundary(or_dataset, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Learnable Bias (XOR)

# %%
pta_xor = Perceptron(epochs=1000, min_error_threshold=0.01)
pta_xor.train(xor_dataset, verbose=0)
# Out:
# (array([-0.753123  , -0.27188785]), 0.5216931426344771)

# %%
pta_xor.plot_decision_boundary(xor_dataset, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Fixed Bias (AND)

# %%
pta_and_fixed_bias = Perceptron(epochs=1000, min_error_threshold=0.01)
pta_and_fixed_bias.train(and_dataset, verbose=0, fixedBias=True, bias=0)
# Out:
# (array([0.56660633, 0.03385796]), 0)

# %%
pta_and_fixed_bias.plot_decision_boundary(and_dataset, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Fixed Bias (OR)

# %%
pta_or_fixed_bias = Perceptron(epochs=1000, min_error_threshold=0.01)
pta_or_fixed_bias.train(or_dataset, verbose=0, fixedBias=True, bias=0)
# Out:
# (array([0.79590982, 0.36439149]), 0)

# %%
pta_or_fixed_bias.plot_decision_boundary(or_dataset, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Fixed Bias (XOR)

# %%
pta_xor_fixed_bias = Perceptron(epochs=1000, min_error_threshold=0.01)
pta_xor_fixed_bias.train(xor_dataset, verbose=0, fixedBias=True, bias=0)
# Out:
# (array([-0.7390791 , -0.02831738]), 0)

# %%
pta_xor_fixed_bias.plot_decision_boundary(xor_dataset, 'Perceptron Decision Boundary')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ASUS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\site-packages\\matplotlib\\pyplot.py'>
